# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 60
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 60:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog

# %%
batch_id = 2
sample_id = 60
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)

batch_id = 1
sample_id = 2
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 60:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog
#
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 2:
# Image - Min Value: 20 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 9 Name: truck

# %%
batch_id = 2
sample_id = 60
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)

batch_id = 5
sample_id = 400
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 60:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog
#
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 400:
# Image - Min Value: 44 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %%
batch_id = 2
sample_id = 60
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)

batch_id = 3
sample_id = 50
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 60:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog
#
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 50:
# Image - Min Value: 5 Max Value: 254
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %%
batch_id = 2
sample_id = 60
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)

batch_id = 4
sample_id = 36
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 60:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog
#
# Stats of batch 4:
# Samples: 10000
# Label Counts: {0: 1003, 1: 963, 2: 1041, 3: 976, 4: 1004, 5: 1021, 6: 1004, 7: 981, 8: 1024, 9: 983}
# First 20 Labels: [0, 6, 0, 2, 7, 2, 1, 2, 4, 1, 5, 6, 6, 3, 1, 3, 5, 5, 8, 1]
#
# Example of Image 36:
# Image - Min Value: 7 Max Value: 249
# Image - Shape: (32, 32, 3)
# Label - Label Id: 7 Name: horse

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return (x / 255)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    output = np.zeros((len(x), max(x)+1))
    output[np.arange(len(x)), x] = 1
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    dimensions = [None,]
    for dim in image_shape:
        dimensions.append(dim)
    x_tensor = tf.placeholder(tf.float32,dimensions,name="x")
    return x_tensor


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y_tensor = tf.placeholder(tf.float32,[None , n_classes],name="y")
    return y_tensor


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob_tensor = tf.placeholder(tf.float32,name="keep_prob")
    return keep_prob_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], int(x_tensor.shape[3]), conv_num_outputs] 
                                             ,stddev=0.1))
    
    bias = tf.Variable(tf.zeros(shape=[conv_num_outputs]))
    
    x_tensor = tf.nn.conv2d(x_tensor , weight ,
                           strides=[1, conv_strides[0], conv_strides[1], 1],
                           padding="SAME")
    
    x_tensor = tf.nn.bias_add(x_tensor ,bias)
    
    x_tensor = tf.nn.relu(x_tensor)
    
    x_tensor = tf.nn.max_pool(x_tensor ,
                              ksize=[1,pool_ksize[0],pool_ksize[1],1] ,
                              strides=[1,pool_strides[0],pool_strides[1],1],
                              padding="SAME"
                             )
                            
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    x_tensor = tf.reshape(x_tensor , [-1 , int(x_tensor.shape[1] * x_tensor.shape[2] * x_tensor.shape[3])])
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.truncated_normal([int(x_tensor.shape[1]),num_outputs],
                                              stddev=0.1))
    
    bias = tf.Variable(tf.zeros(shape=[num_outputs]))
    
    fully_connected_tensor = tf.add(tf.matmul(x_tensor, weights), bias)
    fully_connected_tensor = tf.nn.relu(fully_connected_tensor)
    return fully_connected_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weights = tf.Variable(tf.truncated_normal([int(x_tensor.shape[1]),num_outputs],
                                              stddev=0.1))
    
    bias = tf.Variable(tf.zeros(shape=[num_outputs]))
    
    output_tensor = tf.add(tf.matmul(x_tensor, weights), bias)
    
    return output_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_layer_1 = conv2d_maxpool(x_tensor=x, conv_num_outputs=16, 
                                  conv_ksize=(3,3), conv_strides=(2,2), 
                                  pool_ksize=(2,2), pool_strides=(2,2))
    conv_layer_2 = conv2d_maxpool(x_tensor=conv_layer_1, conv_num_outputs=32, 
                                  conv_ksize=(5,5), conv_strides=(1,1), 
                                  pool_ksize=(2,2), pool_strides=(2,2))
    conv_layer_3 = conv2d_maxpool(x_tensor=conv_layer_2, conv_num_outputs=64, 
                                  conv_ksize=(10,10), conv_strides=(1,1), 
                                  pool_ksize=(2,2), pool_strides=(1,1))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flatten_layer = flatten(conv_layer_3)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc_layer = fully_conn(flatten_layer, 20)
    fc_layer = tf.nn.dropout(fc_layer , keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(fc_layer , 10)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    
    accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    
    print('Loss: {:>15.4f} Validation Accuracy: {:.2f}%'.format(loss, accuracy*100))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:          2.2275 Validation Accuracy: 18.38%
# Epoch  2, CIFAR-10 Batch 1:  Loss:          2.1724 Validation Accuracy: 19.08%
# Epoch  3, CIFAR-10 Batch 1:  Loss:          2.1006 Validation Accuracy: 26.62%
# Epoch  4, CIFAR-10 Batch 1:  Loss:          2.0141 Validation Accuracy: 31.20%
# Epoch  5, CIFAR-10 Batch 1:  Loss:          1.9830 Validation Accuracy: 33.20%
# Epoch  6, CIFAR-10 Batch 1:  Loss:          1.9401 Validation Accuracy: 33.62%
# Epoch  7, CIFAR-10 Batch 1:  Loss:          1.8848 Validation Accuracy: 34.54%
# Epoch  8, CIFAR-10 Batch 1:  Loss:          1.8448 Validation Accuracy: 37.28%
# Epoch  9, CIFAR-10 Batch 1:  Loss:          1.8102 Validation Accuracy: 39.12%
# Epoch 10, CIFAR-10 Batch 1:  Loss:          1.7680 Validation Accuracy: 38.06%
# Epoch 11, CIFAR-10 Batch 1:  Loss:          1.7462 Validation Accuracy: 35.66%
# Epoch 12, CIFAR-10 Batch 1:  Loss:          1.7476 Validation Accuracy: 34.74%
# Epoch 13, CIFAR-10 Batch 1:  Loss:          1.6276 Validation Accuracy: 38.38%
# Epoch 14, CIFAR-10 Batch 1:  Loss:          1.5298 Validation Accuracy: 41.86%
# Epoch 15, CIFAR-10 Batch 1:  Loss:          1.4971 Validation Accuracy: 41.14%
# Epoch 16, CIFAR-10 Batch 1:  Loss:          1.4643 Validation Accuracy: 45.54%
# Epoch 17, CIFAR-10 Batch 1:  Loss:          1.3863 Validation Accuracy: 45.80%
# Epoch 18, CIFAR-10 Batch 1:  Loss:          1.3975 Validation Accuracy: 44.20%
# Epoch 19, CIFAR-10 Batch 1:  Loss:          1.4237 Validation Accuracy: 43.52%
# Epoch 20, CIFAR-10 Batch 1:  Loss:          1.2679 Validation Accuracy: 48.44%
# Epoch 21, CIFAR-10 Batch 1:  Loss:          1.2314 Validation Accuracy: 46.88%
# Epoch 22, CIFAR-10 Batch 1:  Loss:          1.2080 Validation Accuracy: 49.48%
# Epoch 23, CIFAR-10 Batch 1:  Loss:          1.2058 Validation Accuracy: 47.22%
# Epoch 24, CIFAR-10 Batch 1:  Loss:          1.1619 Validation Accuracy: 47.30%
# Epoch 25, CIFAR-10 Batch 1:  Loss:          1.0976 Validation Accuracy: 47.16%
# Epoch 26, CIFAR-10 Batch 1:  Loss:          1.0678 Validation Accuracy: 48.02%
# Epoch 27, CIFAR-10 Batch 1:  Loss:          1.0742 Validation Accuracy: 49.42%
# Epoch 28, CIFAR-10 Batch 1:  Loss:          1.0182 Validation Accuracy: 50.12%
# Epoch 29, CIFAR-10 Batch 1:  Loss:          1.0001 Validation Accuracy: 50.60%
# Epoch 30, CIFAR-10 Batch 1:  Loss:          0.9725 Validation Accuracy: 49.74%
# Epoch 31, CIFAR-10 Batch 1:  Loss:          0.9369 Validation Accuracy: 49.58%
# Epoch 32, CIFAR-10 Batch 1:  Loss:          0.8983 Validation Accuracy: 50.70%
# Epoch 33, CIFAR-10 Batch 1:  Loss:          0.9134 Validation Accuracy: 49.82%
# Epoch 34, CIFAR-10 Batch 1:  Loss:          0.9031 Validation Accuracy: 48.30%
# Epoch 35, CIFAR-10 Batch 1:  Loss:          0.8666 Validation Accuracy: 49.94%
# Epoch 36, CIFAR-10 Batch 1:  Loss:          0.9025 Validation Accuracy: 47.04%
# Epoch 37, CIFAR-10 Batch 1:  Loss:          0.8212 Validation Accuracy: 50.44%
# Epoch 38, CIFAR-10 Batch 1:  Loss:          0.8282 Validation Accuracy: 47.64%
# Epoch 39, CIFAR-10 Batch 1:  Loss:          0.8289 Validation Accuracy: 48.32%
# Epoch 40, CIFAR-10 Batch 1:  Loss:          0.7774 Validation Accuracy: 50.08%
# Epoch 41, CIFAR-10 Batch 1:  Loss:          0.7563 Validation Accuracy: 48.66%
# Epoch 42, CIFAR-10 Batch 1:  Loss:          0.7257 Validation Accuracy: 50.78%
# Epoch 43, CIFAR-10 Batch 1:  Loss:          0.6822 Validation Accuracy: 50.46%
# Epoch 44, CIFAR-10 Batch 1:  Loss:          0.6554 Validation Accuracy: 51.60%
# Epoch 45, CIFAR-10 Batch 1:  Loss:          0.5915 Validation Accuracy: 52.12%
# Epoch 46, CIFAR-10 Batch 1:  Loss:          0.6001 Validation Accuracy: 50.54%
# Epoch 47, CIFAR-10 Batch 1:  Loss:          0.6135 Validation Accuracy: 51.26%
# Epoch 48, CIFAR-10 Batch 1:  Loss:          0.5722 Validation Accuracy: 48.70%
# Epoch 49, CIFAR-10 Batch 1:  Loss:          0.5240 Validation Accuracy: 47.82%
# Epoch 50, CIFAR-10 Batch 1:  Loss:          0.5487 Validation Accuracy: 50.04%

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:          2.2591 Validation Accuracy: 18.22%
# Epoch  1, CIFAR-10 Batch 2:  Loss:          2.0882 Validation Accuracy: 24.38%
# Epoch  1, CIFAR-10 Batch 3:  Loss:          1.7845 Validation Accuracy: 32.92%
# Epoch  1, CIFAR-10 Batch 4:  Loss:          1.8081 Validation Accuracy: 33.42%
# Epoch  1, CIFAR-10 Batch 5:  Loss:          1.8691 Validation Accuracy: 31.96%
# Epoch  2, CIFAR-10 Batch 1:  Loss:          1.9690 Validation Accuracy: 35.86%
# Epoch  2, CIFAR-10 Batch 2:  Loss:          1.7822 Validation Accuracy: 39.36%
# Epoch  2, CIFAR-10 Batch 3:  Loss:          1.5176 Validation Accuracy: 40.72%
# Epoch  2, CIFAR-10 Batch 4:  Loss:          1.5659 Validation Accuracy: 41.26%
# Epoch  2, CIFAR-10 Batch 5:  Loss:          1.5415 Validation Accuracy: 42.60%
# Epoch  3, CIFAR-10 Batch 1:  Loss:          1.6859 Validation Accuracy: 43.96%
# Epoch  3, CIFAR-10 Batch 2:  Loss:          1.6178 Validation Accuracy: 43.58%
# Epoch  3, CIFAR-10 Batch 3:  Loss:          1.3752 Validation Accuracy: 44.14%
# Epoch  3, CIFAR-10 Batch 4:  Loss:          1.4409 Validation Accuracy: 45.70%
# Epoch  3, CIFAR-10 Batch 5:  Loss:          1.4460 Validation Accuracy: 47.52%
# Epoch  4, CIFAR-10 Batch 1:  Loss:          1.5421 Validation Accuracy: 46.06%
# Epoch  4, CIFAR-10 Batch 2:  Loss:          1.5454 Validation Accuracy: 47.52%
# Epoch  4, CIFAR-10 Batch 3:  Loss:          1.1695 Validation Accuracy: 47.12%
# Epoch  4, CIFAR-10 Batch 4:  Loss:          1.3493 Validation Accuracy: 48.72%
# Epoch  4, CIFAR-10 Batch 5:  Loss:          1.3234 Validation Accuracy: 47.58%
# Epoch  5, CIFAR-10 Batch 1:  Loss:          1.3528 Validation Accuracy: 50.22%
# Epoch  5, CIFAR-10 Batch 2:  Loss:          1.3581 Validation Accuracy: 50.40%
# Epoch  5, CIFAR-10 Batch 3:  Loss:          1.0779 Validation Accuracy: 50.68%
# Epoch  5, CIFAR-10 Batch 4:  Loss:          1.2491 Validation Accuracy: 50.80%
# Epoch  5, CIFAR-10 Batch 5:  Loss:          1.2545 Validation Accuracy: 49.78%
# Epoch  6, CIFAR-10 Batch 1:  Loss:          1.2526 Validation Accuracy: 50.18%
# Epoch  6, CIFAR-10 Batch 2:  Loss:          1.2618 Validation Accuracy: 51.42%
# Epoch  6, CIFAR-10 Batch 3:  Loss:          1.0369 Validation Accuracy: 52.78%
# Epoch  6, CIFAR-10 Batch 4:  Loss:          1.2127 Validation Accuracy: 52.80%
# Epoch  6, CIFAR-10 Batch 5:  Loss:          1.1833 Validation Accuracy: 51.28%
# Epoch  7, CIFAR-10 Batch 1:  Loss:          1.1849 Validation Accuracy: 50.62%
# Epoch  7, CIFAR-10 Batch 2:  Loss:          1.1910 Validation Accuracy: 52.48%
# Epoch  7, CIFAR-10 Batch 3:  Loss:          0.9848 Validation Accuracy: 54.38%
# Epoch  7, CIFAR-10 Batch 4:  Loss:          1.0921 Validation Accuracy: 53.26%
# Epoch  7, CIFAR-10 Batch 5:  Loss:          1.1038 Validation Accuracy: 54.04%
# Epoch  8, CIFAR-10 Batch 1:  Loss:          1.1084 Validation Accuracy: 52.64%
# Epoch  8, CIFAR-10 Batch 2:  Loss:          1.0799 Validation Accuracy: 54.70%
# Epoch  8, CIFAR-10 Batch 3:  Loss:          0.9051 Validation Accuracy: 55.74%
# Epoch  8, CIFAR-10 Batch 4:  Loss:          1.0976 Validation Accuracy: 55.42%
# Epoch  8, CIFAR-10 Batch 5:  Loss:          1.0610 Validation Accuracy: 53.96%
# Epoch  9, CIFAR-10 Batch 1:  Loss:          0.9851 Validation Accuracy: 55.38%
# Epoch  9, CIFAR-10 Batch 2:  Loss:          1.0415 Validation Accuracy: 55.90%
# Epoch  9, CIFAR-10 Batch 3:  Loss:          0.8801 Validation Accuracy: 56.60%
# Epoch  9, CIFAR-10 Batch 4:  Loss:          1.0615 Validation Accuracy: 55.64%
# Epoch  9, CIFAR-10 Batch 5:  Loss:          0.9804 Validation Accuracy: 57.04%
# Epoch 10, CIFAR-10 Batch 1:  Loss:          0.9624 Validation Accuracy: 55.50%
# Epoch 10, CIFAR-10 Batch 2:  Loss:          0.9990 Validation Accuracy: 56.08%
# Epoch 10, CIFAR-10 Batch 3:  Loss:          0.8491 Validation Accuracy: 57.30%
# Epoch 10, CIFAR-10 Batch 4:  Loss:          0.9803 Validation Accuracy: 57.24%
# Epoch 10, CIFAR-10 Batch 5:  Loss:          0.9052 Validation Accuracy: 57.06%
# Epoch 11, CIFAR-10 Batch 1:  Loss:          0.9231 Validation Accuracy: 57.02%
# Epoch 11, CIFAR-10 Batch 2:  Loss:          0.9758 Validation Accuracy: 55.02%
# Epoch 11, CIFAR-10 Batch 3:  Loss:          0.7873 Validation Accuracy: 57.50%
# Epoch 11, CIFAR-10 Batch 4:  Loss:          0.9096 Validation Accuracy: 58.28%
# Epoch 11, CIFAR-10 Batch 5:  Loss:          0.8410 Validation Accuracy: 56.42%
# Epoch 12, CIFAR-10 Batch 1:  Loss:          0.9721 Validation Accuracy: 54.68%
# Epoch 12, CIFAR-10 Batch 2:  Loss:          0.8830 Validation Accuracy: 55.56%
# Epoch 12, CIFAR-10 Batch 3:  Loss:          0.7534 Validation Accuracy: 59.22%
# Epoch 12, CIFAR-10 Batch 4:  Loss:          0.8633 Validation Accuracy: 59.34%
# Epoch 12, CIFAR-10 Batch 5:  Loss:          0.7579 Validation Accuracy: 57.88%
# Epoch 13, CIFAR-10 Batch 1:  Loss:          0.8388 Validation Accuracy: 58.36%
# Epoch 13, CIFAR-10 Batch 2:  Loss:          0.8281 Validation Accuracy: 56.10%
# Epoch 13, CIFAR-10 Batch 3:  Loss:          0.7450 Validation Accuracy: 58.58%
# Epoch 13, CIFAR-10 Batch 4:  Loss:          0.8282 Validation Accuracy: 59.36%
# Epoch 13, CIFAR-10 Batch 5:  Loss:          0.7258 Validation Accuracy: 59.30%
# Epoch 14, CIFAR-10 Batch 1:  Loss:          0.7389 Validation Accuracy: 59.38%
# Epoch 14, CIFAR-10 Batch 2:  Loss:          0.7833 Validation Accuracy: 55.66%
# Epoch 14, CIFAR-10 Batch 3:  Loss:          0.6713 Validation Accuracy: 58.68%
# Epoch 14, CIFAR-10 Batch 4:  Loss:          0.7762 Validation Accuracy: 58.86%
# Epoch 14, CIFAR-10 Batch 5:  Loss:          0.6815 Validation Accuracy: 58.98%
# Epoch 15, CIFAR-10 Batch 1:  Loss:          0.7239 Validation Accuracy: 59.74%
# Epoch 15, CIFAR-10 Batch 2:  Loss:          0.7289 Validation Accuracy: 58.14%
# Epoch 15, CIFAR-10 Batch 3:  Loss:          0.6781 Validation Accuracy: 59.36%
# Epoch 15, CIFAR-10 Batch 4:  Loss:          0.7170 Validation Accuracy: 59.84%
# Epoch 15, CIFAR-10 Batch 5:  Loss:          0.6134 Validation Accuracy: 60.22%
# Epoch 16, CIFAR-10 Batch 1:  Loss:          0.6329 Validation Accuracy: 59.64%
# Epoch 16, CIFAR-10 Batch 2:  Loss:          0.6661 Validation Accuracy: 58.36%
# Epoch 16, CIFAR-10 Batch 3:  Loss:          0.6130 Validation Accuracy: 59.48%
# Epoch 16, CIFAR-10 Batch 4:  Loss:          0.6749 Validation Accuracy: 60.44%
# Epoch 16, CIFAR-10 Batch 5:  Loss:          0.5616 Validation Accuracy: 60.16%
# Epoch 17, CIFAR-10 Batch 1:  Loss:          0.6084 Validation Accuracy: 59.76%
# Epoch 17, CIFAR-10 Batch 2:  Loss:          0.5957 Validation Accuracy: 58.00%
# Epoch 17, CIFAR-10 Batch 3:  Loss:          0.5758 Validation Accuracy: 60.54%
# Epoch 17, CIFAR-10 Batch 4:  Loss:          0.6239 Validation Accuracy: 60.36%
# Epoch 17, CIFAR-10 Batch 5:  Loss:          0.5343 Validation Accuracy: 61.42%
# Epoch 18, CIFAR-10 Batch 1:  Loss:          0.5679 Validation Accuracy: 61.60%
# Epoch 18, CIFAR-10 Batch 2:  Loss:          0.5408 Validation Accuracy: 58.54%
# Epoch 18, CIFAR-10 Batch 3:  Loss:          0.4972 Validation Accuracy: 60.36%
# Epoch 18, CIFAR-10 Batch 4:  Loss:          0.5608 Validation Accuracy: 61.62%
# Epoch 18, CIFAR-10 Batch 5:  Loss:          0.5278 Validation Accuracy: 61.56%
# Epoch 19, CIFAR-10 Batch 1:  Loss:          0.5458 Validation Accuracy: 61.24%
# Epoch 19, CIFAR-10 Batch 2:  Loss:          0.4798 Validation Accuracy: 60.30%
# Epoch 19, CIFAR-10 Batch 3:  Loss:          0.4636 Validation Accuracy: 60.12%
# Epoch 19, CIFAR-10 Batch 4:  Loss:          0.5699 Validation Accuracy: 62.60%
# Epoch 19, CIFAR-10 Batch 5:  Loss:          0.4946 Validation Accuracy: 61.98%
# Epoch 20, CIFAR-10 Batch 1:  Loss:          0.5039 Validation Accuracy: 62.26%
# Epoch 20, CIFAR-10 Batch 2:  Loss:          0.4417 Validation Accuracy: 59.20%
# Epoch 20, CIFAR-10 Batch 3:  Loss:          0.4734 Validation Accuracy: 61.32%
# Epoch 20, CIFAR-10 Batch 4:  Loss:          0.5267 Validation Accuracy: 62.10%
# Epoch 20, CIFAR-10 Batch 5:  Loss:          0.5130 Validation Accuracy: 61.90%
# Epoch 21, CIFAR-10 Batch 1:  Loss:          0.4975 Validation Accuracy: 62.28%
# Epoch 21, CIFAR-10 Batch 2:  Loss:          0.4121 Validation Accuracy: 61.36%
# Epoch 21, CIFAR-10 Batch 3:  Loss:          0.4392 Validation Accuracy: 62.04%
# Epoch 21, CIFAR-10 Batch 4:  Loss:          0.4691 Validation Accuracy: 62.26%
# Epoch 21, CIFAR-10 Batch 5:  Loss:          0.4736 Validation Accuracy: 61.48%
# Epoch 22, CIFAR-10 Batch 1:  Loss:          0.4851 Validation Accuracy: 61.66%
# Epoch 22, CIFAR-10 Batch 2:  Loss:          0.3820 Validation Accuracy: 61.66%
# Epoch 22, CIFAR-10 Batch 3:  Loss:          0.4126 Validation Accuracy: 61.64%
# Epoch 22, CIFAR-10 Batch 4:  Loss:          0.4423 Validation Accuracy: 61.92%
# Epoch 22, CIFAR-10 Batch 5:  Loss:          0.4061 Validation Accuracy: 62.04%
# Epoch 23, CIFAR-10 Batch 1:  Loss:          0.4162 Validation Accuracy: 62.06%
# Epoch 23, CIFAR-10 Batch 2:  Loss:          0.4500 Validation Accuracy: 60.28%
# Epoch 23, CIFAR-10 Batch 3:  Loss:          0.3900 Validation Accuracy: 60.72%
# Epoch 23, CIFAR-10 Batch 4:  Loss:          0.3876 Validation Accuracy: 62.76%
# Epoch 23, CIFAR-10 Batch 5:  Loss:          0.3671 Validation Accuracy: 62.70%
# Epoch 24, CIFAR-10 Batch 1:  Loss:          0.4310 Validation Accuracy: 61.72%
# Epoch 24, CIFAR-10 Batch 2:  Loss:          0.3348 Validation Accuracy: 61.98%
# Epoch 24, CIFAR-10 Batch 3:  Loss:          0.3641 Validation Accuracy: 61.30%
# Epoch 24, CIFAR-10 Batch 4:  Loss:          0.3933 Validation Accuracy: 61.58%
# Epoch 24, CIFAR-10 Batch 5:  Loss:          0.3729 Validation Accuracy: 61.44%
# Epoch 25, CIFAR-10 Batch 1:  Loss:          0.3967 Validation Accuracy: 61.44%
# Epoch 25, CIFAR-10 Batch 2:  Loss:          0.3916 Validation Accuracy: 62.32%
# Epoch 25, CIFAR-10 Batch 3:  Loss:          0.3593 Validation Accuracy: 59.72%
# Epoch 25, CIFAR-10 Batch 4:  Loss:          0.3878 Validation Accuracy: 62.24%
# Epoch 25, CIFAR-10 Batch 5:  Loss:          0.3679 Validation Accuracy: 62.00%
# Epoch 26, CIFAR-10 Batch 1:  Loss:          0.3947 Validation Accuracy: 61.82%
# Epoch 26, CIFAR-10 Batch 2:  Loss:          0.3734 Validation Accuracy: 61.46%
# Epoch 26, CIFAR-10 Batch 3:  Loss:          0.3395 Validation Accuracy: 60.70%
# Epoch 26, CIFAR-10 Batch 4:  Loss:          0.3672 Validation Accuracy: 62.20%
# Epoch 26, CIFAR-10 Batch 5:  Loss:          0.3598 Validation Accuracy: 61.44%
# Epoch 27, CIFAR-10 Batch 1:  Loss:          0.3715 Validation Accuracy: 62.64%
# Epoch 27, CIFAR-10 Batch 2:  Loss:          0.3077 Validation Accuracy: 62.66%
# Epoch 27, CIFAR-10 Batch 3:  Loss:          0.3110 Validation Accuracy: 60.24%
# Epoch 27, CIFAR-10 Batch 4:  Loss:          0.3481 Validation Accuracy: 62.46%
# Epoch 27, CIFAR-10 Batch 5:  Loss:          0.2921 Validation Accuracy: 62.94%
# Epoch 28, CIFAR-10 Batch 1:  Loss:          0.3868 Validation Accuracy: 62.44%
# Epoch 28, CIFAR-10 Batch 2:  Loss:          0.2975 Validation Accuracy: 62.52%
# Epoch 28, CIFAR-10 Batch 3:  Loss:          0.3072 Validation Accuracy: 61.16%
# Epoch 28, CIFAR-10 Batch 4:  Loss:          0.3392 Validation Accuracy: 62.66%
# Epoch 28, CIFAR-10 Batch 5:  Loss:          0.2784 Validation Accuracy: 62.12%
# Epoch 29, CIFAR-10 Batch 1:  Loss:          0.3640 Validation Accuracy: 63.16%
# Epoch 29, CIFAR-10 Batch 2:  Loss:          0.3067 Validation Accuracy: 61.30%
# Epoch 29, CIFAR-10 Batch 3:  Loss:          0.3060 Validation Accuracy: 62.12%
# Epoch 29, CIFAR-10 Batch 4:  Loss:          0.3176 Validation Accuracy: 62.48%
# Epoch 29, CIFAR-10 Batch 5:  Loss:          0.2874 Validation Accuracy: 62.48%
# Epoch 30, CIFAR-10 Batch 1:  Loss:          0.3461 Validation Accuracy: 61.98%
# Epoch 30, CIFAR-10 Batch 2:  Loss:          0.3230 Validation Accuracy: 62.62%
# Epoch 30, CIFAR-10 Batch 3:  Loss:          0.2823 Validation Accuracy: 62.22%
# Epoch 30, CIFAR-10 Batch 4:  Loss:          0.3120 Validation Accuracy: 62.06%
# Epoch 30, CIFAR-10 Batch 5:  Loss:          0.2502 Validation Accuracy: 62.38%
# Epoch 31, CIFAR-10 Batch 1:  Loss:          0.3994 Validation Accuracy: 61.20%
# Epoch 31, CIFAR-10 Batch 2:  Loss:          0.2840 Validation Accuracy: 62.00%
# Epoch 31, CIFAR-10 Batch 3:  Loss:          0.2615 Validation Accuracy: 62.06%
# Epoch 31, CIFAR-10 Batch 4:  Loss:          0.3179 Validation Accuracy: 62.60%
# Epoch 31, CIFAR-10 Batch 5:  Loss:          0.2565 Validation Accuracy: 63.26%
# Epoch 32, CIFAR-10 Batch 1:  Loss:          0.3463 Validation Accuracy: 63.16%
# Epoch 32, CIFAR-10 Batch 2:  Loss:          0.2767 Validation Accuracy: 61.14%
# Epoch 32, CIFAR-10 Batch 3:  Loss:          0.2622 Validation Accuracy: 62.26%
# Epoch 32, CIFAR-10 Batch 4:  Loss:          0.3068 Validation Accuracy: 62.58%
# Epoch 32, CIFAR-10 Batch 5:  Loss:          0.2726 Validation Accuracy: 61.82%
# Epoch 33, CIFAR-10 Batch 1:  Loss:          0.3535 Validation Accuracy: 61.02%
# Epoch 33, CIFAR-10 Batch 2:  Loss:          0.2987 Validation Accuracy: 61.36%
# Epoch 33, CIFAR-10 Batch 3:  Loss:          0.2644 Validation Accuracy: 62.18%
# Epoch 33, CIFAR-10 Batch 4:  Loss:          0.3125 Validation Accuracy: 61.42%
# Epoch 33, CIFAR-10 Batch 5:  Loss:          0.2245 Validation Accuracy: 63.32%
# Epoch 34, CIFAR-10 Batch 1:  Loss:          0.3266 Validation Accuracy: 61.32%
# Epoch 34, CIFAR-10 Batch 2:  Loss:          0.2790 Validation Accuracy: 59.70%
# Epoch 34, CIFAR-10 Batch 3:  Loss:          0.2837 Validation Accuracy: 61.80%
# Epoch 34, CIFAR-10 Batch 4:  Loss:          0.2769 Validation Accuracy: 61.44%
# Epoch 34, CIFAR-10 Batch 5:  Loss:          0.1900 Validation Accuracy: 63.58%
# Epoch 35, CIFAR-10 Batch 1:  Loss:          0.3380 Validation Accuracy: 59.68%
# Epoch 35, CIFAR-10 Batch 2:  Loss:          0.2554 Validation Accuracy: 58.28%
# Epoch 35, CIFAR-10 Batch 3:  Loss:          0.2689 Validation Accuracy: 62.44%
# Epoch 35, CIFAR-10 Batch 4:  Loss:          0.2582 Validation Accuracy: 62.14%
# Epoch 35, CIFAR-10 Batch 5:  Loss:          0.1928 Validation Accuracy: 63.26%
# Epoch 36, CIFAR-10 Batch 1:  Loss:          0.2967 Validation Accuracy: 62.20%
# Epoch 36, CIFAR-10 Batch 2:  Loss:          0.2301 Validation Accuracy: 58.96%
# Epoch 36, CIFAR-10 Batch 3:  Loss:          0.2656 Validation Accuracy: 63.18%
# Epoch 36, CIFAR-10 Batch 4:  Loss:          0.2511 Validation Accuracy: 61.28%
# Epoch 36, CIFAR-10 Batch 5:  Loss:          0.1900 Validation Accuracy: 60.86%
# Epoch 37, CIFAR-10 Batch 1:  Loss:          0.3113 Validation Accuracy: 62.18%
# Epoch 37, CIFAR-10 Batch 2:  Loss:          0.2231 Validation Accuracy: 59.96%
# Epoch 37, CIFAR-10 Batch 3:  Loss:          0.2502 Validation Accuracy: 62.34%
# Epoch 37, CIFAR-10 Batch 4:  Loss:          0.2570 Validation Accuracy: 60.34%
# Epoch 37, CIFAR-10 Batch 5:  Loss:          0.2030 Validation Accuracy: 62.16%
# Epoch 38, CIFAR-10 Batch 1:  Loss:          0.3120 Validation Accuracy: 62.18%
# Epoch 38, CIFAR-10 Batch 2:  Loss:          0.2208 Validation Accuracy: 57.82%
# Epoch 38, CIFAR-10 Batch 3:  Loss:          0.2482 Validation Accuracy: 61.86%
# Epoch 38, CIFAR-10 Batch 4:  Loss:          0.2495 Validation Accuracy: 59.70%
# Epoch 38, CIFAR-10 Batch 5:  Loss:          0.1899 Validation Accuracy: 63.98%
# Epoch 39, CIFAR-10 Batch 1:  Loss:          0.2856 Validation Accuracy: 62.66%
# Epoch 39, CIFAR-10 Batch 2:  Loss:          0.1981 Validation Accuracy: 59.72%
# Epoch 39, CIFAR-10 Batch 3:  Loss:          0.2152 Validation Accuracy: 62.38%
# Epoch 39, CIFAR-10 Batch 4:  Loss:          0.2364 Validation Accuracy: 59.96%
# Epoch 39, CIFAR-10 Batch 5:  Loss:          0.1730 Validation Accuracy: 63.52%
# Epoch 40, CIFAR-10 Batch 1:  Loss:          0.3006 Validation Accuracy: 61.78%
# Epoch 40, CIFAR-10 Batch 2:  Loss:          0.2231 Validation Accuracy: 57.78%
# Epoch 40, CIFAR-10 Batch 3:  Loss:          0.1993 Validation Accuracy: 61.84%
# Epoch 40, CIFAR-10 Batch 4:  Loss:          0.2219 Validation Accuracy: 59.70%
# Epoch 40, CIFAR-10 Batch 5:  Loss:          0.1705 Validation Accuracy: 62.88%
# Epoch 41, CIFAR-10 Batch 1:  Loss:          0.3034 Validation Accuracy: 61.58%
# Epoch 41, CIFAR-10 Batch 2:  Loss:          0.1973 Validation Accuracy: 59.42%
# Epoch 41, CIFAR-10 Batch 3:  Loss:          0.1669 Validation Accuracy: 62.24%
# Epoch 41, CIFAR-10 Batch 4:  Loss:          0.2329 Validation Accuracy: 61.26%
# Epoch 41, CIFAR-10 Batch 5:  Loss:          0.1704 Validation Accuracy: 62.52%
# Epoch 42, CIFAR-10 Batch 1:  Loss:          0.3011 Validation Accuracy: 61.50%
# Epoch 42, CIFAR-10 Batch 2:  Loss:          0.1909 Validation Accuracy: 60.10%
# Epoch 42, CIFAR-10 Batch 3:  Loss:          0.1584 Validation Accuracy: 62.72%
# Epoch 42, CIFAR-10 Batch 4:  Loss:          0.2091 Validation Accuracy: 60.86%
# Epoch 42, CIFAR-10 Batch 5:  Loss:          0.1520 Validation Accuracy: 63.28%
# Epoch 43, CIFAR-10 Batch 1:  Loss:          0.2815 Validation Accuracy: 61.32%
# Epoch 43, CIFAR-10 Batch 2:  Loss:          0.2082 Validation Accuracy: 59.74%
# Epoch 43, CIFAR-10 Batch 3:  Loss:          0.1499 Validation Accuracy: 63.12%
# Epoch 43, CIFAR-10 Batch 4:  Loss:          0.2097 Validation Accuracy: 62.20%
# Epoch 43, CIFAR-10 Batch 5:  Loss:          0.1752 Validation Accuracy: 63.22%
# Epoch 44, CIFAR-10 Batch 1:  Loss:          0.2583 Validation Accuracy: 61.86%
# Epoch 44, CIFAR-10 Batch 2:  Loss:          0.1763 Validation Accuracy: 59.96%
# Epoch 44, CIFAR-10 Batch 3:  Loss:          0.1681 Validation Accuracy: 62.94%
# Epoch 44, CIFAR-10 Batch 4:  Loss:          0.1986 Validation Accuracy: 62.26%
# Epoch 44, CIFAR-10 Batch 5:  Loss:          0.1544 Validation Accuracy: 62.72%
# Epoch 45, CIFAR-10 Batch 1:  Loss:          0.2753 Validation Accuracy: 62.92%
# Epoch 45, CIFAR-10 Batch 2:  Loss:          0.1896 Validation Accuracy: 60.84%
# Epoch 45, CIFAR-10 Batch 3:  Loss:          0.1385 Validation Accuracy: 62.50%
# Epoch 45, CIFAR-10 Batch 4:  Loss:          0.1950 Validation Accuracy: 62.56%
# Epoch 45, CIFAR-10 Batch 5:  Loss:          0.1324 Validation Accuracy: 63.24%
# Epoch 46, CIFAR-10 Batch 1:  Loss:          0.2550 Validation Accuracy: 62.26%
# Epoch 46, CIFAR-10 Batch 2:  Loss:          0.1747 Validation Accuracy: 61.16%
# Epoch 46, CIFAR-10 Batch 3:  Loss:          0.1421 Validation Accuracy: 63.06%
# Epoch 46, CIFAR-10 Batch 4:  Loss:          0.1797 Validation Accuracy: 62.38%
# Epoch 46, CIFAR-10 Batch 5:  Loss:          0.1437 Validation Accuracy: 61.94%
# Epoch 47, CIFAR-10 Batch 1:  Loss:          0.2468 Validation Accuracy: 62.76%
# Epoch 47, CIFAR-10 Batch 2:  Loss:          0.1718 Validation Accuracy: 60.74%
# Epoch 47, CIFAR-10 Batch 3:  Loss:          0.1404 Validation Accuracy: 62.76%
# Epoch 47, CIFAR-10 Batch 4:  Loss:          0.1837 Validation Accuracy: 61.88%
# Epoch 47, CIFAR-10 Batch 5:  Loss:          0.1366 Validation Accuracy: 62.56%
# Epoch 48, CIFAR-10 Batch 1:  Loss:          0.2678 Validation Accuracy: 62.70%
# Epoch 48, CIFAR-10 Batch 2:  Loss:          0.1970 Validation Accuracy: 59.60%
# Epoch 48, CIFAR-10 Batch 3:  Loss:          0.1217 Validation Accuracy: 63.84%
# Epoch 48, CIFAR-10 Batch 4:  Loss:          0.1702 Validation Accuracy: 61.62%
# Epoch 48, CIFAR-10 Batch 5:  Loss:          0.1263 Validation Accuracy: 61.94%
# Epoch 49, CIFAR-10 Batch 1:  Loss:          0.2605 Validation Accuracy: 62.14%
# Epoch 49, CIFAR-10 Batch 2:  Loss:          0.1582 Validation Accuracy: 61.32%
# Epoch 49, CIFAR-10 Batch 3:  Loss:          0.1242 Validation Accuracy: 62.34%
# Epoch 49, CIFAR-10 Batch 4:  Loss:          0.1556 Validation Accuracy: 60.90%
# Epoch 49, CIFAR-10 Batch 5:  Loss:          0.1436 Validation Accuracy: 62.20%
# Epoch 50, CIFAR-10 Batch 1:  Loss:          0.2755 Validation Accuracy: 62.18%
# Epoch 50, CIFAR-10 Batch 2:  Loss:          0.1716 Validation Accuracy: 59.62%
# Epoch 50, CIFAR-10 Batch 3:  Loss:          0.1486 Validation Accuracy: 62.00%
# Epoch 50, CIFAR-10 Batch 4:  Loss:          0.1494 Validation Accuracy: 61.84%
# Epoch 50, CIFAR-10 Batch 5:  Loss:          0.1295 Validation Accuracy: 61.88%

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.61533203125

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
